# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.

# %% [markdown]
# ## 0. Load the data
# (Needed before the numbers in Section 3.)

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)

import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
df["is_declining_label"] = df["trend_direction"].str.lower().eq("down").astype(int)
print(df.shape[0], "pages loaded")

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# Lane: Refresh / Content Opportunity Scoring. I chose it because the model already beat a simple hand rule at spotting declining pages in the starter notebooks, and I want to build on that.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# Decision: which pages should be reviewed first.
#
# Action: a reviewer checks flagged pages and decides if they need a refresh.
#
# Cost of wrong call: wasted review time on pages that don't need it, or missing pages that do.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)

# %%
print("Total pages:", df.shape[0])
print("Declining rate:", round(df["is_declining_label"].mean(), 3))

# %% [markdown]
# Precision@50 was 0.24 for the hand rule vs 0.74 for the model — about 3x better.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# These are patterns observed on a small sample only — not proof a refresh will work, and not proof about Google's algorithm.

# %% [markdown]
# ## 5. Self-check
#
# Row = one page. Used the starter dataset. Label is based on trend_direction, not a real future outcome. Hand rule is my baseline. Still need stronger validation.
